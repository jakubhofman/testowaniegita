# %% [markdown]
# <a href="https://colab.research.google.com/github/jakubhofman/testowaniegita/blob/main/test_git_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Jestem w pliku otwartym z dysku')
# Out:
# Jestem w pliku otwartym z dysku

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Colab Notebooks/Test_Gita/testowaniegita
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Test_Gita/testowaniegita
